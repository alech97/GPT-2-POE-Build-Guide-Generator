# %%
import os
import json
import numpy as np
import tensorflow as tf

os.chdir('./gpt2/src')
import model, sample, encoder
from generate_unconditional_samples import sample_model
from interactive_conditional_samples import interact_model
os.chdir('../')

# %%
interact_model(
    model_name='POEModel',
    seed=3,
    nsamples=3,
    batch_size=1,
    length=None,
    top_p=0.8,
    top_k=40
)
# Out:
# WARNING:tensorflow:From c:\users\alec\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Alec\Documents\Data Science\GPT-2-POE-Build-Guide-Generator\gpt2\src\sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\Alec\Documents\Data Science\GPT-2-POE-Build-Guide-Generator\gpt2\src\sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From c:\users\alec\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models\POEModel\model-207
# Model prompt >>> [3.7] The Warchief | [Facebreaker] Ancestral Warchief | 2m dps+ | Uber Farmer| Elder & Shaper Down
# ======================================== SAMPLE 1 ========================================
#
#
# http://www.pathofexile.com/forum/view-thread/244870/page/2
#
# Videos
#
#
#
#
#
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.7 - Warchief Power Build - Melee DPS - Spell DPS
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# 3.6 - Melee DPS - Faster Attacks - Spell DPS
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.5 - Melee DPS - Melee Crit Chance - Spell Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.4 - Melee DPS - Spell Crit Chance - Melee Power - Melee Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.3 - Weapon Crit Chance - Weapon Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.2 - Weapon Crit Chance - Weapon Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.1 - Weapon Crit Chance - Weapon Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 3.0 - Weapon Crit Chance - Weapon Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.8 - Faster Attacks - Melee Crit Chance - Spell Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.7 - Faster Attacks - Spell Crit Chance - Melee Power - Melee Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.6 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.5 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.4 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.3 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.2 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.1 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# 2.0 - Faster Attacks - Spell Crit Chance - Spell Crit Damage - Weapon Crit Chance
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________________________________________________________________________________________________________________________________________
#
# ________________________________________________________________
# ======================================== SAMPLE 2 ========================================
#
#
# Fully Clear the first chest in the zone
#
# http://www.youtube.com/watch?v=yjtRg3O7A5c
#
# http://www.youtube.com/watch?v=_-Pb_b7LkjU
#
# Reward: Infernal Blow, Pierce, and Aspect of the Pines.
#
# Recommended character: Shaper (Druid)
# My build, at lvl 77, did 70%+ dps with totem. As you can see, totem has only 5% crit chance, the crit % being entirely or mostly from weapon and not the life based crit chance.
#
# Weapon
#
# Blade/Sceptre:
#
# 3L: Grasping at Shadows
# 1L: Blood Rage
# 2L: Temporal Chains
# 3L: Summon Lightning Golem
# 4L: Warlord's Mark
# 5L: Grasping at Shadows
# 6L: Warlord's Mark
#
# Shield
#
# Void Battery:
#
# 2L: Cold to Frost
# 3L: Chaos Orb
# 4L: Feral Spirit
# 5L: Spell Totem
#
# Helm:
#
# Herald of Ash:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Gloves:
#
# Void Battery:
#
# 2L: Frost Blades
# 3L: Summon Lightning Golem
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Boots:
#
# Void Battery:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Shoulders:
#
# Void Battery:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Belt:
#
# Herald of Ash:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Gloves:
#
# Void Battery:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's Mark
# 5L: Frost Blades
#
# Shield:
#
# Void Battery:
#
# 2L: Summon Lightning Golem
# 3L: Herald of Ice
# 4L: Warlord's
# ======================================== SAMPLE 3 ========================================
# . One of the better Dps's in the game.
#
#
#  [3.8] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#  [3.9] The Crusader | [Facebreaker] Crusader | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
# [3.10] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
# [3.11] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
# [3.12] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
#
#
# [3.13] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
#
# [3.14] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
# [3.15] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
# [3.16] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
#
# [3.17] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
# [3.18] The Juggernaut | [Facebreaker] Juggernaut | 2m dps+ | Uber Farmer| Elder & Shaper Down. One of the best Dps's in the game.
#
#
#
#
#
# [3.19]
# ================================================================================
# Model prompt >>> [3.7] EARTHQUAKE JUGGERNAUT | Tanky Beast [VIDEO]
# ======================================== SAMPLE 1 ========================================
#  https://www.youtube.com/watch?v=xI_ZpOVX3J0
#
#
#
# http://youtu.be/UzyYPCnVpUQ
#
#
#
#
# - TANK:
#
# + Get some free defense, since this build has no defensive equipment.
# + Weapon:
# - Avoid all possible insta-gank range - This is a very good thing. Even though this build is very mobile, if the enemy can get away from you fast enough, they will be much less likely to attack you.
# - Shield:
# - Focus on hitting the enemies directly - This will boost your survivability a lot, since you can easily block their attacks.
#
#
# *Not Recommended*
#
#
#
#
# [3.8] EARTHQUAKE SCARNER | Brutal Berserker [VIDEO] https://www.youtube.com/watch?v=W_iI2xj_Tpw
#
#
#
# - Weapon:
# - This build is really strong because you can reach full tankiness easily, which is not possible with all the "meta" builds. So this is the only weapon I really recommend, and why it is recommended.
#
#
#
# - Shield:
# - Use a shield with high max health, like pure Mjollnir, instead of a shield that has a high defense.
#
#
#
# *Not Recommended*
#
#
#
#
# [3.9] EARTHQUAKE WARRIOR | Brutal Beast [VIDEO] https://www.youtube.com/watch?v=VxZnB9OK2cI
#
#
# - Weapon:
# - You have to decide between a weapon with a high attack speed, like Mjollnir, and a weapon with a high defense, like Mjollnir +2. It depends on the build, but if you're aiming for tankiness, use either of these.
#
#
# - Shield:
# - Use a shield with high max health, like pure Mjollnir, instead of a shield that has a high defense.
#
#
#
# *Not Recommended*
#
#
#
#
# [3.10] EARTHQUAKE LEADER | Battlecrier [VIDEO] https://www.youtube.com/watch?v=YGmKqj-uqCk
#
#
# - Weapon:
# - If you want to play a tanky beast build, this is the way to go. But if you want to play a
# ======================================== SAMPLE 2 ========================================
#  | [5.0] EARTHQUAKE JUGGERNAUT | Brawler [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Utility [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Juggernaut [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Assassin [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Scion [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Elemental Expert [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Elemental Ranger [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Hunter [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Berserker [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Arc Warden [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Holy Guardian [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Immortal [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | LoS [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Merciless [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Jita [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | PTR [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Lightning [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Melee [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Tanky [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Brawler [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Utility [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Juggernaut [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT | Scion [VIDEO] | [5.0] EARTHQUAKE JUGGERNAUT
# ======================================== SAMPLE 3 ========================================
#
#
# EARTHQUAKE JUGGERNAUT | Utility Buff [VIDEO]
#
# EARTHQUAKE JUGGERNAUT | Rapid Attack [VIDEO]
#
# EARTHQUAKE JUGGERNAUT | Manta Style [VIDEO]
#
# EARTHQUAKE JUGGERNAUT | Spell Burst [VIDEO]
#
# Earthquake Juggernaut
#
# HALF DIAGRAM SCALE-UP IS AVAILABLE
#
# HALF DIAGRAM SCALE-UP IS AVAILABLE
#
# (Linking)
#
# <link>
#
# XBOX
#
# GRAVITY MINIMIZE: LINK
#
# HALF DIAGRAM SCALE-UP IS AVAILABLE
#
# GRAVITY MINIMIZE: LINK
#
# XBOX
#
# HALF DIAGRAM SCALE-UP IS AVAILABLE
#
# HALF DIAGRAM SCALE-UP IS AVAILABLE
#
# (Linking)
#
# <link>
#
# This is a video of the MIDNIGHT FUNNIES build. I'm doing a general discussion on my builds with the other teams and some members of the reddit guild. Enjoy.
#
#
# HELP!
#
# Want to talk about any of the builds I've played? Talk to me on irc.rizon.net
# <link>
#
# 1:1 CHANCES
#
# 1:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1:1:
#
# 2:1
# ================================================================================
# Model prompt >>> [4.0] EARTHQUAKE JUGGERNAUT | Tanky Beast
# ======================================== SAMPLE 1 ========================================
#  (with +6.0COLD BUFF!) | RIP SWEEPER - Heartbreaker
#
# Level 58 | LVL 64 | COMPLETE at the end of Last Boss: Entering the Burial Ground - Drop Level 6
#
# Build:
#
#
#
#
# + Added Lightning Damage: YES
#
#
#
# + Armor: YES
#
#
# + Crit Multi: YES
#
#
# + Resists: YES
#
#
# + Health: YES
#
#
# + Weapon Elemental Damage: YES
#
#
#
# Level 60 | LVL 65 | COMPLETE at the end of Last Boss: Entering the Burial Ground - Drop Level 7
#
# Build:
#
#
#
#
#
#
#
#
# + Added Lightning Damage: YES
#
#
# + Armor: YES
#
#
# + Crit Multi: YES
#
#
# + Resists: YES
#
#
# + Health: YES
#
#
# + Weapon Elemental Damage: YES
#
#
# Level 70 | LVL 69 | COMPLETE at the end of Last Boss: Entering the Burial Ground - Drop Level 8
#
# Build:
#
#
#
#
#
#
# + Added Lightning Damage: YES
#
#
# + Armor: YES
#
#
# + Crit Multi: YES
#
#
# + Resists: YES
#
#
# + Health: YES
#
#
# + Weapon Elemental Damage: YES
#
#
#
# Level 80 | LVL 80 | COMPLETE at the end of Last Boss: Entering the Burial Ground - Drop Level 9
#
# Build:
#
#
#
#
#
#
#
#
# + Added Lightning Damage: YES
#
#
# + Armor: YES
#
#
# + Crit Multi: YES
#
#
# + Resists: YES
#
#
# + Health: YES
#
#
# + Weapon Elemental Damage: YES
#
#
# Level 90 | LVL 91 | COMPLETE at the end of Last Boss: Entering the Burial Ground - Drop Level 10
#
# Build:
#
#
#
#
#
#
#
#
# + Added Lightning Damage: YES
#
#
# + Armor: YES
#
#
# + Crit Multi: YES
#
#
# + Resists: YES
#
#
# + Health: YES
#
#
# + Weapon Elemental Damage: YES
#
#
#
#
#
# | End|
#
# | --|-----|--|--|-----|--|-----|-----|
#
# |-----------------------------|-----------------------------|-----------------------------|
#
# | | Deca|Ancilla|Sveta|Lunaris|Sores|Aether|Blacks|Draug|Sucara|Sorona|Cybele|Kyros|Igneous|Valkyrie|
#
# |---|---|---|---|---
# ======================================== SAMPLE 2 ========================================
# , Critical Damage, Good Endurance, Good Frenzy Charges, Great Crit Chance.
#
#
# Juggernaut :
#
# Increases your Endurance Charge Duration and Critical Strike Chance, and gives you Critical Strike Damage, but your Endurance Charge Duration is reduced. Also gives you a Free Frenzy Charge, which you can use to sustain your Frenzy Charges.
#
# Cons:
#
# 1. Lower Endurance Charge Duration, so you need to increase Endurance Charge Duration if you want to sustain Endurance Charge Duration, and your Endurance Charge Duration is reduced.
# 2. Low Critical Strike Chance
#
# 3. Low Crit Damage, but good damage in general.
#
# Shaman :
#
# Increases your Magic Damage, Endurance Charge Duration, and Critical Strike Chance, but the bonuses are slightly reduced.
#
# Cons:
# 1. Low Endurance Charge Duration, so you need to increase Endurance Charge Duration if you want to sustain Endurance Charge Duration, and your Endurance Charge Duration is reduced.
#
# 2. Low Critical Strike Chance, but good damage in general.
#
# Witch :
#
# Increases your Attack Speed, Mana, and Mana Regeneration.
#
# Cons:
# 1. Low Mana Regeneration, so you need to increase Mana Regeneration to keep up your Mana Regeneration.
#
# 2. Low Mana Regeneration, so you need to increase Mana Regeneration if you want to sustain Mana Regeneration, and your Mana Regeneration is reduced.
#
# Hunter :
#
# Increases your Attack Speed, Mana, and Mana Regeneration, and you can use one Endurance Charge on each Critical Strike.
#
# Cons:
# 1. Low Mana Regeneration, so you need to increase Mana Regeneration to keep up your Mana Regeneration.
#
# 2. Low Mana Regeneration, so you need to increase Mana Regeneration if you want to sustain Mana Regeneration, and your Mana Regeneration is reduced.
#
# Ranger :
#
# Increases your Attack Speed, Mana, and Mana Regeneration.
#
# Cons:
# 1. Low Mana Regeneration, so you need to increase Mana Regeneration to keep up your Mana Regeneration.
#
# 2. Low Mana Regeneration, so you need to increase Mana Regeneration if you want to sustain Mana Regeneration, and your Mana Regeneration is reduced.
#
# Templar :
#
# Increases your Attack Speed, Mana, and Mana Regeneration.
#
# Cons:
# 1. Low Mana Regeneration, so you need to increase Mana Regeneration to keep up your Mana Regeneration.
#
# 2. Low
# ======================================== SAMPLE 3 ========================================
#  | Early Game - Mid Game
#
#
# | PASSIVE: Each rune gives a buff to allies. Each buff gives 4% extra HP for a total of 9%.
# | WEAPON: Weapon buffs us to 8% more HP.
#
#
# | MORE ADRENAL IS GOOD! --> The Passive: We have 30% more HP, 30% more armour, and 30% more attack speed. The ADRENAL is nice and important in this build. If you have a lot of AP, you want the buffs to be as good as possible.
#
# | USEFUL IDEAS: Some items are extremely useful. We have everything from boots to gloves, we can swap them out for things we can build more for, or we can build something else.
#
# | DO NOT USE THIS! If you are a ninja that plays with teammates, this is an absolute waste of your items.
#
# | GOING FOR A SHOTGUN, NOT AN ARROW. --> We have the 8% MORE ATTACK SPEED, so what do we really need? We don't have a shield so we can't build anything that we would be able to build for damage, and we don't have the shield to really make up for it, so the extra health is useless.
#
# | GOING FOR THE STACKER, NOT THE GEAR. --> The shield and armour give us much more armour than an arrow, so we need to be careful about the shield to make up for the loss of armour. If we take it, we don't really need the shields.
#
# | GOING FOR A BRACELET, NOT A JUGGLE. --> The Jewel gives a damage bonus, so we need to make sure that we can get something else to compensate for the loss of armour.
#
# | GOING FOR A GUN, NOT A JAGGER. --> We don't have the armor to really get the full bonus from a hammer, so we need to be careful about the damage bonus.
#
# | GOING FOR THE GEAR, NOT THE JUGGERNAUT. --> The defence, life, and mana are all really useless in this build, so we don't really need the defensive items.
#
#
#
#
#
#
# "Just here for you, all of you," says Kimono Sentence, speaking of a friend who's always been here for us.
# "So how are you doing, all of you?" "You guys have really helped me out," says
# ================================================================================
# Model prompt >>> [3.7][HC] Caustic Arrow Raider | Tanky | All Content
# ======================================== SAMPLE 1 ========================================
#
#
# I've been trying to figure out what role this build is intended for, and here's the answer: This build is great for DPS. Caustic Arrow is a good addition to any DPS build, as the nice crit is mitigated by aura levels, and the projectile damage is at a reasonable distance (more than enough to one shot you in. The bow itself is still fine, but at least for now, I've decided not to bother trying to come up with a bow spec that works well with this build.
#
# Also, for all the fine tuning and playtesting of this build, it will be only 1,850 CDR, so expect more rares/rare maps in the near future. This is probably the weakest point of the build, because you can get out of it faster and more efficiently than it was intended.
#
# Link to first page: http://www.pathofexile.com/forum/view-thread/171915/page/1
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
#
# Just got back from the 11th at the end of 2015. Started HCing the first time around and this is the first time I have done a full league without any difficulty. Last year I was doing a full league so there wasn't much to say about it, but in 2017 I had to put it all together, so I'm just waiting for all the relevant information and potential surprises to come out.
#
# That being said, I think this build is a great one for almost everyone. There is plenty of room for improvement, so if you like to mess around with builds, this build is a great way to go for that.
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
#
# Need some advice?
# This build uses energy shield. So if you want to make it an accurate RF build, you can increase your life leech in the tooltip to 5% per stack, which will net you 12% increased energy shield for the cost of 2.5% life. This is only for the base build, but you could do it with some non-cast build. I don't know how the gear works, but if you go for the 6L you can get up to 10% life leech, so feel free to try it out.
#
# Answered by: raythebat
#
# ______________________________________________________________
#
# WTB one handed sword (gloves)
#
#
# Throws
#
#
#
#
#
# Video
#
#
#
# Lightning Sword
#
#
#
#
# Bows
# ======================================== SAMPLE 2 ========================================
#  (link)
#
#
# Recommended Gear
#
# Spoiler
#
#
#
#
#
#
#
# Leveling Guide
#
#
#
#
# I decided to split up this build so I don't have to make any choices, as my DPS is much better than that of the 2 main builds (CI/CI+RD)
#
# Skill Tree
#
# Spoiler
#
#
#
# Jewels and Gems
#
#
#
#
# Link to Jewels (dont forget to link the passive tree aswell, you can take the Templar one from the Scion Tree)
#
# Link to Gems (you can use these with the Passive Tree or skip them, I chose the Scion one since I don't have the time to go for the Templar one)
#
# Links
#
#
#
# Skill Tree
#
# I took the High Life, +3% Melee Attack Speed, ES/ES/ES, 3% More Mana, Life/Cast Speed, Increased Area of Effect and the 1% Weapon and Spell Damage nodes for the extra damage and they provide a nice bonus, can also take the higher level jewel if you want to get more life and less Cast Speed.
#
# Jewels and Gems
#
# Some items can't be taken in this build due to the tree, but you can use the one with the +20% Life, Physical Damage, Added Fire Damage, Mana Regeneration and the 3% More Mana node in it. You can take the Wand/Two Handed Tabula Rasa/Two Handed Duelist/Melee Physical damage, Melee Physical Damage, Melee Splash, Added Fire Damage, Added Cold Damage, Melee Physical Projectile and Added Cold Damage for the extra damage.
#
# Link to Jewels
#
# Some items can't be taken in this build due to the tree, but you can use the one with the +20% Life, Physical Damage, Added Fire Damage, Mana Regeneration and the 3% More Mana node in it. You can take the Wand/Two Handed Tabula Rasa/Two Handed Duelist/Melee Physical damage, Melee Physical Damage, Melee Splash, Added Fire Damage, Added Cold Damage, Melee Physical Projectile and Added Cold Damage for the extra damage.
#
# Stats
#
# Leveling
#
#
# Endgame Build
#
#
#
# Other Builds
#
#
#
#
#
#
#
#
#
# 1.2.0! This build is slightly outdated, but you can get away with it.
#
#
#
# This build is a good one, but in the end you still have to die on the 2nd part of the tree to
# ======================================== SAMPLE 3 ========================================
#
#
# Another full armor-based raider build, it's on a slight rise since the addition of Claw of the Destroyer. At level 77 I had a couple very clear clear speed runs and still have the damage to go around it, even with very few hitpoints left.
#
#
# I had a couple clear speed runs and still have the damage to go around it, even with very few hitpoints left.
#
# For the most part I can go ahead and slot Vorici as an end-game jeweler, but it might be possible to just replace Vorici for an Aegis of Agony, which will give me some more defense against physical.
#
#
# Vorici's:
# I wouldn't recommend Vorici over other the other jewels for a few reasons:
# 1. Vorici is cheaper (approximately 10c per jewel)
# 2. Vorici will cost more points, but if you have an armour-based raider you can use Vorici's in combination with Kaom's Heart to further increase the defence.
# 3. Vorici is pretty easy to get wrong. I found out the hard way.
#
#
# Warlord's Mark
#
# Warlord's Mark - Increases the chance to get a chest piece
#
#
#
#
# Gloves
#
# Flammable gloves - Max resistances are very nice for these builds, but a helmet is always nice for saving a slot. A Vaal Hatred helmet will give you more defence than a Sceptre and gives you more protection from physical and elemental.
#
# 3L:
#
# Weapon: Bringer of Rain - Blood Rage - Elemental Proliferation - Increased Duration
#
# Helmet: Bringer of Rain - Blood Rage - Increased Duration - Added Fire Damage - Increased Area of Effect
#
# I would recommend the following for these two builds:
# 1. Bringer of Rain - Blood Rage - Elemental Proliferation - Increased Duration
# 2. Bringer of Rain - Blood Rage - Elemental Proliferation - Increased Duration - Added Fire Damage - Increased Area of Effect
#
# I would recommend the following for these two builds:
# 1. Bringer of Rain - Blood Rage - Increased Duration - Added Fire Damage - Increased Area of Effect - Elemental Proliferation
#
# A pair of Auras (Aura of Hope and Aura of Warding) for 2 Mana
#
# A high mana shield with Atziri's Promise and Rumi's Grace for max life.
#
# Gloves:
#
# One Br
# ================================================================================
